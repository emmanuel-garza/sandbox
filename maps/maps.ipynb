# %% [markdown]
# # Playing with Maps
# `I have this idea of using a map with the state size representating some metric`
#
#
# ## References:
# * https://medium.com/@erikgreenj/mapping-us-states-with-geopandas-made-simple-d7b6e66fa20d

# %%
import geopandas as gpd
from shapely.geometry import Point, Polygon
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
usa = gpd.read_file('./states_21basic/states.shp')

# %%
usa.head()
# Out:
#      STATE_NAME  DRAWSEQ STATE_FIPS          SUB_REGION STATE_ABBR  \
# 0        Hawaii        1         15             Pacific         HI
# 1    Washington        2         53             Pacific         WA
# 2       Montana        3         30            Mountain         MT
# 3         Maine        4         23         New England         ME
# 4  North Dakota        5         38  West North Central         ND
#
#                                             geometry
# 0  MULTIPOLYGON (((-160.07380 22.00418, -160.0497...
# 1  MULTIPOLYGON (((-122.40202 48.22522, -122.4628...
# 2  POLYGON ((-111.47543 44.70216, -111.48080 44.6...
# 3  MULTIPOLYGON (((-69.77728 44.07415, -69.85993 ...
# 4  POLYGON ((-98.73044 45.93827, -99.00683 45.939...

# %%
usa.plot(figsize=(20,20))

# %%
ax = usa[usa.STATE_ABBR == 'TX'].plot()

ax = usa[usa.STATE_ABBR == 'CA'].geometry.scale(1).plot(ax=ax)

ax = usa[usa.STATE_ABBR == 'CA'].geometry.scale(0.5,0.5).plot(ax=ax,color='r')


tmp = usa[usa.STATE_ABBR == 'CA']

# %%
usa[usa.STATE_ABBR == 'CA'].geometry
# Out:
# 24    MULTIPOLYGON (((-121.66522 38.16929, -121.7823...
# Name: geometry, dtype: geometry

# %%
dir(usa[usa.STATE_ABBR == 'CA'].geometry)

p = usa[usa.STATE_ABBR == 'CA'].geometry

# %%
p.scale()
# Out:
# 24    MULTIPOLYGON (((-121.66522 38.16929, -121.7823...
# dtype: geometry

# %%
p.scale(100)
# Out:
# 24    MULTIPOLYGON (((-359.888 38.169, -371.602 38.0...
# dtype: geometry
